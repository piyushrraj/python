# %%
import re
m=re.search(r"\d+","Age is 21")
print(m)
print(m.group())
# Out:
# <re.Match object; span=(7, 9), match='21'>
# 21

# %%
import re
m=re.search(r"\d{5,10}","Age is 2123767")
print(m)
print(m.group())
# Out:
# <re.Match object; span=(7, 14), match='2123767'>
# 2123767

# %%
import re
print(re.search(r"ab*", "abbbbba"))
# Out:
# <re.Match object; span=(0, 6), match='abbbbb'>

# %%
import re
print(re.search(r"\d*", "hjehfebfah abbbabb 56478"))
# Out:
# <re.Match object; span=(0, 0), match=''>

# %%
import re
print(re.search(r"colou?r","colour"))
# Out:
# <re.Match object; span=(0, 6), match='colour'>

# %%
#lambda function
even_odd=lambda n:"Even" if n%2==0 else "Odd"
even_odd(9)
# Out:
# 'Odd'

# %%
sum3=lambda a,b,c:a+b+c
sum3(2,6,8)
# Out:
# 16
