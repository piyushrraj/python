# %%
class   Bank():
    Name = "SBI"
    Address = "Haldia"
    pincde="6376327"
    IFSC="SBI1872"

# %%
p1=Bank()
p2=Bank()
p3=Bank()
p1.uname="Piyush"
p1.email="abcd@gmail.com"
p1.surname="raj"
p2.uname="abc"
p2.email="p2@gmail.com"
p2.surname="abcd"

# %%
p1.Address
# Out:
# 'Haldia'

# %%
class  Bank():
    Name = "SBI"
    Address = "Haldia"
    pincde="6376327"
    IFSC="SBI1872"
    def set_details(obj,name,age,phone,pan,balance):
        obj.name=name
        obj.age=age
        obj.pan=pan
        obj.balance=balance
#creating objects
c1=Bank()
c1.set_details("Aditya", 22, 9837483, "ASJSHJDS", 50000)
c2=Bank()
c2.set_details("hsdjfgh", 23, 32947973, "JFGHIRGH", 60000)

# %%
#using _init_ method
class  Bank():
    B_Name = "SBI"
    Address = "Haldia"
    pincde="6376327"
    IFSC="SBI1872"
    helpLine="1700-11-2211"
    def __init__(self, name, age, phone, pan, balance):
        self.name=name
        self.age=age
        self.phone=phone
        self.pan=pan
        self.balance=balance

c1=Bank("Aditya", 22, 9837483, "ASJSHJDS", 50000)
c2=Bank("hsdjfgh", 23, 32947973, "JFGHIRGH", 60000)
c1.name
# Out:
# 'Aditya'

# %%
#Methods:-
class  Bank():
    B_Name = "SBI"
    Address = "Haldia"
    pincde="6376327"
    IFSC="SBI1872"
    helpLine="1700-11-2211"
    def __init__(self, name, age, phone, pan, balance):
        self.name=name
        self.age=age
        self.phone=phone
        self.pan=pan
        self.balance=balance
    def display(self):
        print(self.name,self.phone,self.balance)
    def change_phone(self,new_phone):
        self.phone=new_phone
    def withdraw_money(self,widhdra_balance):
        if(widhdra_balance>0):
            if(self.balance>=widhdra_balance):
                print(widhdra_balance)
            self.balance-=widhdra_balance
        else:
            print("incorrect amount")

# %%
c1=Bank("Aditya", 22, 9837483, "ASJSHJDS", 50000)
c1.withdraw_money(300)
# Out:
# 300

# %%
class Bank():
    B_Name = "SBI"
    Address = "Haldia"
    pincde="6376327"
    IFSC="SBI1872"
    helpLine="1700-11-2211"
    #Constructor
    def __init__(self, name, age, phone, pan, balance):
        self.name=name
        self.age=age
        self.phone=phone
        self.pan=pan
        self.balance=balance
    def display(self):
        print(self.name,self.phone,self.balance)
#Class Method
    @classmethod
    def change_add(cls, new_name):
        Bank.Address=new_name
Bank.change_add("Kolkata")
Bank.Address
# Out:
# 'Kolkata'
