# %%
a = 10 + 2j
id(a)
# Out:
# 1710776298544

# %%
type(a)
# Out:
# complex

# %%
s = 'hit'
id(s)
# Out:
# 1710710229616

# %%
type(s)
# Out:
# str

# %%
a:float = 10

# %%
type(a)
# Out:
# int

# %%
s = "     PYTHON-is-a programming language 123  "

# %%
s.upper()
# Out:
# '     PYTHON-IS-A PROGRAMMING LANGUAGE 123  '

# %%
s.lower()
# Out:
# '     python-is-a programming language 123  '

# %%
s.capitalize()
# Out:
# '     python-is-a programming language 123  '

# %%
s.title()
# Out:
# '     Python-Is-A Programming Language 123  '

# %%
s.isupper()
# Out:
# False

# %%
s.islower()
# Out:
# False

# %%
s.isdigit()
# Out:
# False

# %%
s.isalpha()
# Out:
# False

# %%
s.count('PYTHON')
# Out:
# 1

# %%
s.replace('PYTHON', 'JAVA')
# Out:
# '     JAVA-is-a programming language 123  '

# %%
s.split('-')
# Out:
# ['     PYTHON', 'is', 'a programming language 123  ']

# %%
s.strip()
# Out:
# 'PYTHON-is-a programming language 123'

# %%
s.lstrip()
# Out:
# 'PYTHON-is-a programming language 123  '

# %%
s.rstrip()
# Out:
# '     PYTHON-is-a programming language 123'

# %%
lst = [1, 2, 3, 4]

# %%
lst.append(5)

# %%
lst
# Out:
# [1, 2, 3, 4, 5]

# %%
lst.extend([6, 7, 8])
lst
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
lst.insert(0, 0)

# %%
lst
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
lst.remove(5)
lst
# Out:
# [0, 1, 2, 3, 4, 6, 7, 8]

# %%
lst.pop()
lst
# Out:
# [0, 1, 2, 3, 4, 6, 7]

# %%
lst.index(30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 lst.index(30)
#
# ValueError: 30 is not in list

# %%
lst.append(2)

# %%
lst
# Out:
# [0, 1, 2, 3, 4, 6, 7, 2]

# %%
lst.sort()

# %%
lst
# Out:
# [0, 1, 2, 2, 3, 4, 6, 7]

# %%
lst.reverse()

# %%
lst
# Out:
# [7, 6, 4, 3, 2, 2, 1, 0]

# %%
lst.sort(reverse=True)

# %%
lst
# Out:
# [7, 6, 4, 3, 2, 2, 1, 0]

# %%
t = (1, 2, 3)
t
# Out:
# (1, 2, 3)

# %%
type(t)
# Out:
# tuple

# %%
tuple()
# Out:
# ()

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
t.count(2)
# Out:
# 1

# %%
d = {'a': 1, 'b': 2, 'c': 3}
d
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
d.get('a')
# Out:
# 1

# %%
d.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
d.values()
# Out:
# dict_values([1, 2, 3])

# %%
d.items()
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])

# %%
d.pop('b')
# Out:
# 2

# %%
d
# Out:
# {'a': 1, 'c': 3}

# %%
s1 = set()
type(s1)
# Out:
# set

# %%
s1.add(2)
s1.add(3)
s1
# Out:
# {2, 3}

# %%
s1 = {10, 20, 2, 3, 5, 9, 7, 6}

# %%
s1
# Out:
# {2, 3, 5, 6, 7, 9, 10, 20}

# %%
s2 = s1.copy()

# %%
s2
# Out:
# {2, 3, 5, 6, 7, 9, 10, 20}

# %%
s1.add(100)

# %%
s1
# Out:
# {2, 3, 5, 6, 7, 9, 10, 20, 100}

# %%
s2
# Out:
# {2, 3, 5, 6, 7, 9, 10, 20}

# %%
s2.pop()
# Out:
# 2

# %%
s2.remove(10)

# %%
s2
# Out:
# {3, 5, 6, 7, 9, 20}

# %%
s2.remove(1000)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 s2.remove(1000)
#
# KeyError: 1000

# %%
s2.discard(6)

# %%
s2
# Out:
# {3, 5, 7, 9, 20}

# %%
s2.discard(1000)

# %%
s2
# Out:
# {3, 5, 7, 9, 20}

# %%
b = 3 and 0
b
# Out:
# 0

# %%
bin(10)
# Out:
# '0b1010'

# %%
hex(16)
# Out:
# '0x10'

# %%
20^30
# Out:
# 10

# %%
2^3
# Out:
# 1

# %%
r = [1, 2, 3]
s = r
t = [1, 2, 3]

# %%
r is s
# Out:
# True

# %%
r is t
# Out:
# False

# %%
r is not t
# Out:
# True

# %%
a = input()
a
# Out:
# '7'

# %%
type(a)
# Out:
# str

# %%
len(a)
# Out:
# 1

# %%
a = eval(input("Enter a value: "))

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
type(a)
# Out:
# list

# %%
num = 15
if num % 3 == 0 and num % 5 == 0:
    print("Divisible by both 3 and 5")
# Out:
# Divisible by both 3 and 5

# %%
num = 20
if num % 3 == 0 and num % 5 == 0:
    print("Divisible by both 3 and 5")

# %%
age = eval(input("Enter your age: "))
if age >= 18 and age <=25:
    print("Eligible for vote.")
# Out:
# Eligible for vote.

# %%
num = -11
if num >= 0:
    print("Positive number")
else:
    print("Negative number")
# Out:
# Negative number

# %%
marks = eval(input("Enter marks: "))
if marks >= 90:
    print("A")
elif marks >= 75:
    print("B")
elif marks >= 60:
    print("C")
else:
    print("Fail")
# Out:
# A

# %%
ch = input("Enter a character: ")
if ch.isupper():
    print("Uppercase character")
elif ch.islower():
    print("Lowercase character")
elif ch.isdigit():
    print("Digit")
else:
    print("Special character")
# Out:
# Special character

# %%
experience = eval(input("Enter years of experience: "))
performance_rating = eval(input("Enter performance rating(0-5): "))
if experience >= 5:
    if performance_rating >= 4:
        print("20% bonus")
    else:
        print("10% bonus")
else:
    print("No bonus")
# Out:
# 20% bonus

# %%
no = eval(input("Enter a number: "))
if no >= 0:
    if no%2==0:
        print("Even")
    else:
        print("Odd")
else:
    print("Negative Number")
# Out:
# Negative Number

# %%
pin = 1234
a = eval(input("Enter pin: "))
balance = 70000
withdraw = eval(input("Enter withdrawl amount: "))
if a == pin:
    if balance>=withdraw:
        print("Transcation Successful")
    else:
        print("Insuffecient balance")
else:
    print("Incorrect pin")
# Out:
# Incorrect pin
