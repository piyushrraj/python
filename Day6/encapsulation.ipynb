# %%
#private Method
class Temp:
    def __init__(self):
        self.__var=10
    def get(self):
        print(self.__var)
    def set(self,new_val):
        self.__var=new_val
obj = Temp()
obj.get()
obj.set(30)
obj.get()
# Out:
# 10
# 30
